# %%
from langchain_ollama import ChatOllama
llm = ChatOllama(model="gemma3:4b")

# %%
res = llm.invoke("hello, i am Nikunj")
print(res.content)
# Out:
# Hello Nikunj! It's nice to meet you. 😊
#
# What can I do for you today? Do you want to:
#
# *   Chat about something specific?
# *   Play a game?
# *   Ask me a question?

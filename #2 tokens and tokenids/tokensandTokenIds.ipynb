# %%
text= "Who is Pm of India ?"

# %%
import tiktoken

# %%
tokenizer = tiktoken.encoding_for_model("gpt-4")

# %%
tokenIds = tokenizer.encode(text)
print(tokenIds)
# Out:
# [15546, 374, 393, 76, 315, 6890, 949]

# %%
resultIDs= [47, 76, 315, 28811, 374, 67432, 35489]

# %%
resultword = tokenizer.decode(resultIDs)
resultword
# Out:
# 'Pm of india is Narendra Modi'

# %% [markdown]
# ### Memory with Content RE-Querring.

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model="gpt-4o")

# %%
history = []

while True:
    prompt = input("User: ")
    if prompt.lower() in ["stop","end","close"]:
        print("bye bye")
        break
    history.append({"role":"user","content": prompt})
    print(prompt) 

    res = llm.invoke(history)
    history.append({"role":"ai","content":res.content})
    print(res.content)
# Out:
# my name is Nikunj and my girlfriend name is Pranali
# Nice to meet you, Nikunj—and hello to Pranali!
# How can I help: a cute message, caption, poem, couple hashtag, or something else? Tell me the occasion and language (English/Hindi/Marathi).
#
# Sample to start:
# “Dear Pranali, every day with you feels like a little miracle. —Nikunj”
#
# Also, would you like me to remember your names for future chats?
# what is my name?
# Your name is Nikunj.
# and who is my girlfriend?
# Your girlfriend is Pranali.
# bye bye

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model="gpt-4o",streaming=True)

# %%
prompt = [
    {"role":"user","content":"how is the Pm of india?"}
]

# %%
response = llm.stream(prompt)
for chunk in response:
    print(chunk.content,end="")
# Out:
# As of my last update in October 2023, the Prime Minister of India is Narendra Modi. He has been in office since May 2014, after being elected as the leader of the Bharatiya Janata Party (BJP). Please verify with a current source to ensure there have been no recent changes.

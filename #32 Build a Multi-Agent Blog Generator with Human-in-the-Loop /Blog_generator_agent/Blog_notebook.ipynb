# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from state import BlogState
from agents import get_llm,research_agent

# %%
llm = get_llm()

# %%
from graph import build_blog_graph
from langgraph.types import Command

# %%
graph=build_blog_graph()

# %%
from IPython.display import Image
display(Image(graph.get_graph().draw_mermaid_png()))

# %%
config = {"configurable": {"thread_id": "1"}}

# %%
state = graph.invoke(
    {
        "topic":"mcp for 2026 developer guide",
         "audience":"ai and agentic ai developers"
      },
        config=config 
     )

# %%
snap = graph.get_state(config)

# %%
snap = graph.get_state(config)
interrupt_payload = snap.interrupts[0].value
print("stage",interrupt_payload.get("stage"))
print("\n---------\n")
print(interrupt_payload.get("research"))
# Out:
# stage researcher_review
#
# ---------
#
# **Research Outline – “MCP for 2026: A Developer’s Guide”**
# *Audience: General readers (non‑experts) interested in emerging tech*
#
# ---
#
# ### 1. What is MCP 2026?
# - **Key facts**:
#   - MCP (Micro‑controller Platform) 2026 is the next-gen framework for IoT devices.
#   - Supports 32‑bit ARM Cortex‑M7 cores, 1 GB RAM, 4 GB flash.
#   - Built‑in AI accelerator for edge ML.
# - **Hook**: “Imagine your home appliances learning from you—MCP 2026 makes that a reality.”
#
# ### 2. Why 2026? The Market & Tech Drivers
# - **Stats**:
#   - Global IoT market projected $1.2 trillion by 2026.
#   - 70% of new devices will need AI inference at the edge.
# - **Examples**:
#   - Smart factories using real‑time predictive maintenance.
#   - Consumer wearables with on‑device health analytics.
# - **Angle**: “The year 2026 isn’t just a date—it’s a tipping point for edge computing.”
#
# ### 3. Core Features of MCP 2026
# - **Hardware**:
#   - Dual‑core ARM Cortex‑M7 + AI coprocessor.
#   - 5 G LTE‑Cat M1/NB‑IoT radio.
# - **Software stack**:
#   - RTOS‑based kernel with deterministic latency.
#   - Modular middleware (MQTT, CoAP, OPC‑UA).
# - **Security**:
#   - Secure boot, hardware‑based encryption, OTA updates.
# - **Hook**: “One platform that covers everything from sensor to cloud—no more fragmented stacks.”
#
# ### 4. Development Workflow & Toolchain
# - **Tools**:
#   - IDE: MCP Studio (VS Code extension).
#   - Debugger: JTAG + SWO trace.
#   - CI/CD: GitHub Actions + MCP Build Server.
# - **Process**:
#   - Model‑first design → auto‑generated firmware.
#   - Simulate in MCP‑Sim before hardware.
# - **Example**: Step‑by‑step build of a temperature‑monitoring sensor.
# - **Angle**: “Build faster, debug smarter, ship safer—MCP 2026 streamlines the entire dev cycle.”
#
# ### 5. AI/ML at the Edge with MCP
# - **Capabilities**:
#   - On‑device inference (TensorFlow Lite Micro).
#   - Federated learning support.
# - **Use‑cases**:
#   - Predictive maintenance in factories.
#   - Voice‑activated home assistants with privacy‑first design.
# - **Stats**:
#   - Edge inference latency < 10 ms on MCP 2026.
# - **Hook**: “No cloud? No problem. Your device learns, adapts, and protects itself.”
#
# ### 6. Security & Compliance
# - **Standards**:
#   - ISO 27001, GDPR, and industry‑specific certifications (Automotive ISO 26262).
# - **Features**:
#   - Hardware‑rooted attestation.
#   - Secure OTA with cryptographic signatures.
# - **Example**: Case study of a medical device passing FDA and HIPAA audits.
# - **Angle**: “Security isn’t an add‑on—it’s baked into every silicon line.”
#
# ### 7. Ecosystem & Community Support
# - **Partners**:
#   - Major silicon vendors (NXP, STMicroelectronics).
#   - Cloud providers (AWS IoT Greengrass, Azure IoT Edge).
# - **Resources**:
#   - MCP Developer Hub, forums, open‑source libraries.
#   - Annual MCP Hackathon (2026 edition).
# - **Hook**: “Join a global network of innovators—your code can power the next wave of IoT.”
#
# ---
#
# **Suggested Overall Hook/Angle**
# > “MCP 2026 isn’t just a platform—it’s the launchpad for the next generation of intelligent, secure, and connected devices. Whether you’re a hobbyist or a seasoned engineer, this guide shows you how to build the future, one chip at a time.”

# %%
state = graph.invoke(
    Command(resume={"action":"approve","feedback":""}),
    config=config
    )

# %%
snap = graph.get_state(config)
interrupt_payload = snap.interrupts[0].value
print("stage",interrupt_payload.get("stage"))
print("\n---------Draft---------\n")
print(interrupt_payload.get("draft"))
# Out:
# stage draft_review
#
# ---------Draft---------
#
# # 🚀 Mastering MCP 2026: The Ultimate Developer’s Playbook
#
# **MCP** – the *Modern Cloud Platform* that’s redefining how we build, deploy, and scale applications in 2026 – is finally here. Whether you’re a seasoned architect or a hobbyist just starting out, this guide will walk you through the essentials, from first‑time setup to advanced patterns that keep your code clean, resilient, and future‑proof.
#
# > **TL;DR**:
# > *MCP 2026* is a cloud‑native, micro‑service‑oriented platform that unifies compute, storage, networking, and AI services under a single, declarative API. This guide covers installation, core concepts, best practices, and a sneak‑peek at the roadmap.
#
# ---
#
# ## 1. Why MCP 2026? The New Cloud Paradigm
#
# MCP 2026 is built on a **service‑mesh** foundation, enabling developers to:
#
# | Feature | What It Means | Why It Matters |
# |---------|---------------|----------------|
# | **Zero‑config networking** | Auto‑discovery and secure routing between services | Eliminates manual load‑balancer setup |
# | **AI‑first observability** | Built‑in telemetry, auto‑scaling, and anomaly detection | Faster debugging, less ops overhead |
# | **Composable services** | Plug‑and‑play modules (DB, cache, auth) | Rapid prototyping, lower vendor lock‑in |
# | **Edge‑first delivery** | Native CDN & serverless functions | Faster global response times |
#
# If you’ve been juggling Kubernetes, Terraform, and a dozen CI/CD tools, MCP 2026 offers a single, declarative language to orchestrate everything. It’s the *“one‑stop shop”* for modern cloud development.
#
# ---
#
# ## 2. Getting Started – Your First MCP Project
#
# ### 2.1 Install the CLI
#
# ```bash
# curl -fsSL https://mcp.io/install.sh | sh
# mcp version
# ```
#
# The CLI (`mcp`) is your command center: create projects, deploy services, and view metrics.
#
# ### 2.2 Scaffold a New App
#
# ```bash
# mcp init my‑awesome‑app
# cd my-awesome-app
# ```
#
# The scaffold generates:
#
# - `service.yaml` – service definition
# - `Dockerfile` – container build instructions
# - `README.md` – project docs
#
# ### 2.3 Deploy to MCP
#
# ```bash
# mcp deploy
# ```
#
# The CLI pushes your container to MCP’s registry, registers the service, and exposes it via the platform’s internal DNS (`my-awesome-app.mcp.io`). In minutes, your app is live and reachable from anywhere.
#
# ---
#
# ## 3. Core Concepts – What Makes MCP Tick
#
# | Concept | Short Description | Practical Tip |
# |---------|-------------------|---------------|
# | **Service Mesh** | Transparent communication layer between micro‑services | Use `mcp mesh enable` to auto‑inject sidecars |
# | **Declarative API** | JSON/YAML files define infrastructure | Keep `service.yaml` under version control |
# | **Event Bus** | Pub/Sub system for inter‑service events | Leverage `mcp event subscribe` for reactive patterns |
# | **Policy Engine** | Fine‑grained RBAC & compliance rules | Define policies in `policy.yaml` for auditability |
#
# ### 3.1 Service Definition – The `service.yaml` Blueprint
#
# ```yaml
# apiVersion: mcp.io/v1
# kind: Service
# metadata:
#   name: my-awesome-app
# spec:
#   image: registry.mcp.io/my-awesome-app:latest
#   replicas: 3
#   ports:
#     - name: http
#       port: 80
#       targetPort: 8080
#   env:
#     - name: DATABASE_URL
#       valueFrom:
#         secretKeyRef:
#           name: db-credentials
#           key: url
# ```
#
# Key takeaways:
#
# - **Immutable deployments**: Every change creates a new version; rollbacks are instant.
# - **Secrets management**: No hard‑coded passwords; secrets are encrypted at rest and injected at runtime.
#
# ---
#
# ## 4. Best Practices – Writing Code That Lives in the Cloud
#
# | Practice | Why It Helps | Example |
# |----------|--------------|---------|
# | **Idempotent APIs** | Avoid duplicate work on retries | Use `idempotency-key` header |
# | **Graceful degradation** | Keep core features working when downstream services fail | Circuit breakers via `mcp circuit` |
# | **Observability first** | Faster incident response | Enable `mcp monitor enable` for all services |
# | **Immutable infrastructure** | Consistency across environments | Tag images with semantic versioning |
#
# ### 4.1 Observability – The Heartbeat of MCP
#
# MCP’s observability stack automatically collects logs, metrics, and traces. To enrich telemetry:
#
# ```bash
# mcp monitor enable
# mcp trace inject
# ```
#
# Your dashboards now show latency distributions, error rates, and real‑time traffic patterns—all in a single pane.
#
# ### 4.2 Security – Zero‑Trust by Default
#
# MCP enforces **least‑privilege** access. Define roles in `policy.yaml`:
#
# ```yaml
# apiVersion: mcp.io/v1
# kind: Policy
# metadata:
#   name: read-only
# spec:
#   rules:
#     - apiGroups: ["*"]
#       resources: ["*"]
#       verbs: ["get", "list", "watch"]
# ```
#
# Attach policies to service accounts, and MCP will refuse any unauthorized calls.
#
# ---
#
# ## 5. Future‑Proofing – What’s Next for MCP 2026?
#
# | Feature | Status | How to Get Involved |
# |---------|--------|---------------------|
# | **Quantum‑Ready Compute** | Beta | Submit use‑case proposals via the MCP portal |
# | **Cross‑Cloud Federation** | GA | Use `mcp federate` to connect AWS, Azure, and GCP resources |
# | **AI‑Driven Auto‑Scaling** | Roadmap | Enable experimental flag `mcp autoscale ai=true` |
#
# MCP’s open‑source core means you can contribute patches, propose new modules, or even host your own MCP cluster. The community forum is buzzing with ideas—join the conversation and shape the platform’s evolution.
#
# ---
#
# ## 6. Wrap‑Up – Your MCP Journey Starts Now
#
# MCP 2026 is more than a new platform; it’s a shift in how developers think about cloud infrastructure. By embracing its declarative model, built‑in observability, and zero‑trust security, you can focus on writing great code rather than wrestling with ops.
#
# **Next steps:**
#
# 1. **Install the CLI** and scaffold your first project.
# 2. **Explore the docs** at [docs.mcp.io](https://docs.mcp.io).
# 3. **Join the community** on Discord and GitHub to stay ahead of the curve.
#
# Happy coding, and may your deployments be ever‑green! 🌱

# %%
state = graph.invoke(
    Command(resume={"action":"approve","feedback":""}),
    config=config
    )

# %%
state = graph.invoke(
    Command(resume={"action":"approve","feedback":""}),
    config=config
    )

# %%
print("------------FInal Blog-------------\n")
print(state["final_blog"])
# Out:
# ------------FInal Blog-------------
#
# # Mastering MCP 2026: Your Complete Developer Guide
#
# **MCP** – the Modern Cloud Platform – is changing how we build, deploy, and scale applications in 2026. Whether you’re an experienced architect or a beginner, this guide walks you through everything you need to get started, from installation to advanced patterns that keep your code clean, resilient, and ready for the future.
#
# > **TL;DR**
# > MCP 2026 is a cloud‑native, micro‑service‑oriented platform that brings compute, storage, networking, and AI services under one declarative API. This guide covers installation, core concepts, best practices, and a look at the roadmap.
#
# ---
#
# ## 1. Why MCP 2026? The New Cloud Paradigm
#
# MCP 2026 is built on a service‑mesh foundation, giving developers:
#
# | Feature | What It Means | Why It Matters |
# |---------|---------------|----------------|
# | Zero‑config networking | Auto‑discovery and secure routing between services | No manual load‑balancer setup |
# | AI‑first observability | Built‑in telemetry, auto‑scaling, and anomaly detection | Faster debugging, less ops work |
# | Composable services | Plug‑and‑play modules (DB, cache, auth) | Rapid prototyping, lower vendor lock‑in |
# | Edge‑first delivery | Native CDN and serverless functions | Faster global response times |
#
# If you’ve been juggling Kubernetes, Terraform, and many CI/CD tools, MCP 2026 offers a single, declarative language to orchestrate everything. It’s the one‑stop shop for modern cloud development.
#
# ---
#
# ## 2. Getting Started – Your First MCP Project
#
# ### 2.1 Install the CLI
#
# ```bash
# curl -fsSL https://mcp.io/install.sh | sh
# mcp version
# ```
#
# The `mcp` CLI is your command center: create projects, deploy services, and view metrics.
#
# ### 2.2 Scaffold a New App
#
# ```bash
# mcp init my-awesome-app
# cd my-awesome-app
# ```
#
# The scaffold creates:
#
# - `service.yaml` – service definition
# - `Dockerfile` – container build instructions
# - `README.md` – project documentation
#
# ### 2.3 Deploy to MCP
#
# ```bash
# mcp deploy
# ```
#
# The CLI pushes your container to MCP’s registry, registers the service, and exposes it via the platform’s internal DNS (`my-awesome-app.mcp.io`). In minutes, your app is live and reachable from anywhere.
#
# ---
#
# ## 3. Core Concepts – What Makes MCP Tick
#
# | Concept | Short Description | Practical Tip |
# |---------|-------------------|---------------|
# | Service Mesh | Transparent communication layer between micro‑services | Use `mcp mesh enable` to auto‑inject sidecars |
# | Declarative API | JSON/YAML files define infrastructure | Keep `service.yaml` under version control |
# | Event Bus | Pub/Sub system for inter‑service events | Use `mcp event subscribe` for reactive patterns |
# | Policy Engine | Fine‑grained RBAC and compliance rules | Define policies in `policy.yaml` for auditability |
#
# ### 3.1 Service Definition – The `service.yaml` Blueprint
#
# ```yaml
# apiVersion: mcp.io/v1
# kind: Service
# metadata:
#   name: my-awesome-app
# spec:
#   image: registry.mcp.io/my-awesome-app:latest
#   replicas: 3
#   ports:
#     - name: http
#       port: 80
#       targetPort: 8080
#   env:
#     - name: DATABASE_URL
#       valueFrom:
#         secretKeyRef:
#           name: db-credentials
#           key: url
# ```
#
# Key takeaways:
#
# - **Immutable deployments**: Every change creates a new version; rollbacks are instant.
# - **Secrets management**: No hard‑coded passwords; secrets are encrypted at rest and injected at runtime.
#
# ---
#
# ## 4. Best Practices – Writing Code That Lives in the Cloud
#
# | Practice | Why It Helps | Example |
# |----------|--------------|---------|
# | Idempotent APIs | Avoid duplicate work on retries | Use `idempotency-key` header |
# | Graceful degradation | Keep core features working when downstream services fail | Circuit breakers via `mcp circuit` |
# | Observability first | Faster incident response | Enable `mcp monitor enable` for all services |
# | Immutable infrastructure | Consistency across environments | Tag images with semantic versioning |
#
# ### 4.1 Observability – The Heartbeat of MCP
#
# MCP’s observability stack automatically collects logs, metrics, and traces. To enrich telemetry:
#
# ```bash
# mcp monitor enable
# mcp trace inject
# ```
#
# Your dashboards now show latency distributions, error rates, and real‑time traffic patterns—all in one place.
#
# ### 4.2 Security – Zero‑Trust by Default
#
# MCP enforces least‑privilege access. Define roles in `policy.yaml`:
#
# ```yaml
# apiVersion: mcp.io/v1
# kind: Policy
# metadata:
#   name: read-only
# spec:
#   rules:
#     - apiGroups: ["*"]
#       resources: ["*"]
#       verbs: ["get", "list", "watch"]
# ```
#
# Attach policies to service accounts, and MCP will refuse any unauthorized calls.
#
# ---
#
# ## 5. Future‑Proofing – What’s Next for MCP 2026?
#
# | Feature | Status | How to Get Involved |
# |---------|--------|---------------------|
# | Quantum‑Ready Compute | Beta | Submit use‑case proposals via the MCP portal |
# | Cross‑Cloud Federation | GA | Use `mcp federate` to connect AWS, Azure, and GCP resources |
# | AI‑Driven Auto‑Scaling | Roadmap | Enable experimental flag `mcp autoscale ai=true` |
#
# MCP’s open‑source core lets you contribute patches, propose new modules, or host your own cluster. The community forum is active—join the conversation and shape the platform’s evolution.
#
# ---
#
# ## 6. Wrap‑Up – Your MCP Journey Starts Now
#
# MCP 2026 is more than a new platform; it’s a shift in how developers think about cloud infrastructure. By embracing its declarative model, built‑in observability, and zero‑trust security, you can focus on writing great code instead of wrestling with operations.
#
# **Next steps:**
#
# 1. Install the CLI and scaffold your first project.
# 2. Explore the documentation at [docs.mcp.io](https://docs.mcp.io).
# 3. Join the community on Discord and GitHub to stay ahead of the curve.
#
# Happy coding, and may your deployments stay green!

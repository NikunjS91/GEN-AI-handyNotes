# %% [markdown]
# ### Load ENV Varibles

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# ### Connect with OpenAi

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model="gpt-5")

# %%
res = llm.invoke("who won ipl 2024?")

# %%
print(res.content)
# Out:
# Kolkata Knight Riders (KKR) won the 2024 IPL, defeating Sunrisers Hyderabad in the final.

# %% [markdown]
# ### Connect with Google gemini model.

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm = ChatGoogleGenerativeAI(model="gemini-3.1-flash-lite")

# %%
res = llm.invoke("what is GenAI? Explain me in short?")

# %%
print(res.content)
# Out:
# [{'type': 'text', 'text': '**Generative AI (GenAI)** is a type of artificial intelligence that can **create new content** rather than just analyzing existing data.\n\nWhile traditional AI is used to classify information or make predictions (like "is this email spam?"), Generative AI produces original outputs such as:\n\n*   **Text:** Writing emails, essays, or code (e.g., ChatGPT).\n*   **Images:** Creating photorealistic art or graphics (e.g., Midjourney, DALL-E).\n*   **Audio/Video:** Generating music, voice clones, or video clips from text prompts.\n\n### How does it work?\nIt is built on "Large Models" that have been trained on massive amounts of data from the internet. By learning the underlying patterns and structures of that data, the AI can predict what should come next in a sequence. \n\n**In short:** If traditional AI is like a **librarian** (who finds the right book for you), Generative AI is like an **author** (who writes a brand-new book for you).', 'extras': {'signature
# ...

# %% [markdown]
# ### Connect with Anthropic model.

# %%
from langchain_anthropic import ChatAnthropic
llm = ChatAnthropic(model="claude-sonnet-4-5-20250929")

# %%
res = llm.invoke("capital of india is?")

# %%
print(res.content)
# Out:
# The capital of India is **New Delhi**.
#
# New Delhi serves as the seat of all three branches of the Government of India and is located within the larger metropolis of Delhi (National Capital Territory of Delhi).

# %% [markdown]
# ### static prompting

# %%
from langchain_anthropic import ChatAnthropic
llm = ChatAnthropic(model="claude-sonnet-4-5-20250929")

# %%
prompt=[
    ("system","you are a python developer"),
    ("user","write a python code to print hello world")
]
res = llm.invoke(prompt)

# %%
print(res.content)
# Out:
# Here's a simple Python code to print "Hello World":
#
# ```python
# print("Hello World")
# ```
#
# If you want a more elaborate version with a function:
#
# ```python
# def hello_world():
#     print("Hello World")
#
# # Call the function
# hello_world()
# ```
#
# Or with a main block (common practice in Python):
#
# ```python
# def main():
#     print("Hello World")
#
# if __name__ == "__main__":
#     main()
# ```
#
# All three versions will output:
# ```
# Hello World
# ```
#
# The first one is the simplest and most direct way to print "Hello World" in Python! 🐍

# %% [markdown]
# ### Correct prompt structure.

# %%
from langchain_anthropic import ChatAnthropic
llm = ChatAnthropic(model="claude-sonnet-4-5-20250929")

# %%
prompt=[
    {"role":"system","content":"you are a translator convert the text to marathi?"},
    {"role":"user","content":"i like to eat pizza and burger."}
]

res= llm.invoke(prompt)

# %%
print(res.content)
# Out:
# मला पिझ्झा आणि बर्गर खायला आवडते.
#
# (Malā pizzā āṇi bargar khāylā āvaḍatē.)

# %% [markdown]
# ### Prompt Templates: Dynamic Prompts.

# %%
from langchain_anthropic import ChatAnthropic
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
llm = ChatAnthropic(model="claude-sonnet-4-5-20250929")
out = StrOutputParser()

# %%
prompt= ChatPromptTemplate.from_messages([
    {"role":"system","content":"you are a translator so translate the input message into {language}"},
    {"role":"user","content": "{query}"}
])
prompt
# Out:
# ChatPromptTemplate(input_variables=['language', 'query'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=['language'], input_types={}, partial_variables={}, template='you are a translator so translate the input message into {language}'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['query'], input_types={}, partial_variables={}, template='{query}'), additional_kwargs={})])

# %%
final_prompts= prompt.format_messages(language="hinglish", query="i like to eat pasta and pizza")
res = llm.invoke(final_prompts)

# %%
print(res.content)
# Out:
# mujhe pasta aur pizza khana pasand hai

# %% [markdown]
# ### chaining

# %%
chains = prompt | llm | out
chains
# Out:
# ChatPromptTemplate(input_variables=['language', 'query'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=['language'], input_types={}, partial_variables={}, template='you are a translator so translate the input message into {language}'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['query'], input_types={}, partial_variables={}, template='{query}'), additional_kwargs={})])
# ...

# %%
res = chains.invoke({"language":"Hinglish","query":"i love to eat mango ?"})
print(res)
# Out:
# मुझे आम खाना बहुत पसंद है।
#
# or
#
# Mujhe aam khaana bahut pasand hai.
